# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT / "src"))

# %%
from config import BEST_HUMAN_CUES_PATH, CATEGORY_PROMPT_CANDIDATES_PATH
from prompt_utils import build_all_category_prompt_candidates

# %%
best_human_df = pd.read_csv(BEST_HUMAN_CUES_PATH)
subcategories = sorted(best_human_df["subcategory"].dropna().unique().tolist())

print("Subcategories:")
print(subcategories)
# Out:
# Subcategories:
# ['交通場所', '交通工具', '休閒娛樂', '動作', '動物', '喝', '娛樂場所', '學校', '家具', '廚房用品', '文具', '服飾&配件', '水果', '生活用品', '蔬菜', '調味', '購物場所', '輔具', '運動場所', '醫療場所', '金融機構', '電器用品', '食物', '餐具']

# %%
category_prompt_df = build_all_category_prompt_candidates(subcategories)
category_prompt_df.head(20)
# Out:
#    subcategory prompt_id  prompt_family     prompt_variant  \
# 0         交通場所  交通場所_p01  category_meta       v1_meta_base
# 1         交通場所  交通場所_p02  category_meta  v2_discriminative
# 2         交通場所  交通場所_p03  category_meta    v3_life_context
# 3         交通工具  交通工具_p01  category_meta       v1_meta_base
# 4         交通工具  交通工具_p02  category_meta  v2_discriminative
# 5         交通工具  交通工具_p03  category_meta    v3_life_context
# 6         休閒娛樂  休閒娛樂_p01  category_meta       v1_meta_base
# 7         休閒娛樂  休閒娛樂_p02  category_meta  v2_discriminative
# 8         休閒娛樂  休閒娛樂_p03  category_meta    v3_life_context
# 9           動作    動作_p01  category_meta       v1_meta_base
# 10          動作    動作_p02  category_meta  v2_discriminative
# 11          動作    動作_p03  category_meta    v3_life_context
# 12          動物    動物_p01  category_meta       v1_meta_base
# 13          動物    動物_p02  category_meta  v2_discriminative
# 14          動物    動物_p03  category_meta    v3_life_context
# ...

# %%
category_prompt_df.to_csv(CATEGORY_PROMPT_CANDIDATES_PATH, index=False, encoding="utf-8-sig")
print("Saved:", CATEGORY_PROMPT_CANDIDATES_PATH)
# Out:
# Saved: C:\Users\804\Dtx_Projects\Aphasia_APE_Cue_Generator\data\interim\category_prompt_candidates.csv
