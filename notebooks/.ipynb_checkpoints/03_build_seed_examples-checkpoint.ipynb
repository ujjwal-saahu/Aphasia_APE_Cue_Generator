# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT / "src"))

# %%
from config import BEST_HUMAN_CUES_PATH, SEED_EXAMPLES_PATH
from prompt_utils import build_seed_examples

# %%
best_human_df = pd.read_csv(BEST_HUMAN_CUES_PATH)
seed_df = build_seed_examples(best_human_df, top_k_per_subcategory=5)

print(seed_df.shape)
seed_df[["subcategory", "target_word", "cue_text", "score_mean"]].head(20)
# Out:
# (77, 12)
#    subcategory target_word               cue_text  score_mean
# 0         交通場所          機場             內部有免稅商店和餐廳    5.666667
# 1         交通工具         摩托車           需要加汽油或電力才能運行    5.666667
# 2         交通工具          汽車               需要加油才能行駛    5.333333
# 3         交通工具         自行車               運動或代步皆適合    5.000000
# 4         交通工具          高鐵        透過電力驅動,行駛於專用軌道上    5.000000
# 5         交通工具          公車                   票價便宜    4.666667
# 6         休閒娛樂          購物          節日會推出促銷活動吸引客人    5.666667
# 7         休閒娛樂          唱歌  有時會搭配樂器,如吉他、鋼琴或卡拉OK伴奏    5.666667
# 8         休閒娛樂          看書           會用手翻頁或摺角作為書籤    5.333333
# 9         休閒娛樂          登山         有可能會碰到熊,要有防熊噴霧    5.333333
# 10        休閒娛樂          跳舞         與拍手、踩腳或轉圈的動作結合    5.333333
# 11          動作         擦桌子         在餐廳、學校、辦公室都很常見    6.000000
# 12          動作          睡覺      適當的時間內完成這件事,有助於健康    6.000000
# 13          動作         穿衣服               可以做不同的搭配    5.666667
# ...

# %%
seed_df.to_csv(SEED_EXAMPLES_PATH, index=False, encoding="utf-8-sig")
print("Saved:", SEED_EXAMPLES_PATH)
# Out:
# Saved: c:\Users\804\Dtx_Projects\Aphasia_APE_Cue_Generator\data\processed\seed_examples.csv
